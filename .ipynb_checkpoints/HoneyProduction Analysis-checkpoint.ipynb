# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('honeyproduction.csv')
df.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
df.describe(include='all')
# Out:
#        state         numcol  yieldpercol     totalprod        stocks  \
# count    626     626.000000   626.000000  6.260000e+02  6.260000e+02
# unique    44            NaN          NaN           NaN           NaN
# top       AR            NaN          NaN           NaN           NaN
# freq      15            NaN          NaN           NaN           NaN
# mean     NaN   60284.345048    62.009585  4.169086e+06  1.318859e+06
# std      NaN   91077.087231    19.458754  6.883847e+06  2.272964e+06
# min      NaN    2000.000000    19.000000  8.400000e+04  8.000000e+03
# 25%      NaN    9000.000000    48.000000  4.750000e+05  1.430000e+05
# 50%      NaN   26000.000000    60.000000  1.533000e+06  4.395000e+05
# 75%      NaN   63750.000000    74.000000  4.175250e+06  1.489500e+06
# max      NaN  510000.000000   136.000000  4.641000e+07  1.380000e+07
#
#         priceperlb     prodvalue         year
# count   626.000000  6.260000e+02   626.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB

# %% [markdown]
# ## unique states and their count

# %%
df['state'].unique()
# Out:
# array(['AL', 'AZ', 'AR', 'CA', 'CO', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN',
#        'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MI', 'MN', 'MS', 'MO', 'MT',
#        'NE', 'NV', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA',
#        'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'SC'],
#       dtype=object)

# %%
df['state'].nunique()  #there are 44 states in data
# Out:
# 44

# %%
df['state'].value_counts()
# Out:
# AR    15
# AZ    15
# FL    15
# IL    15
# VA    15
# SD    15
# VT    15
# MN    15
# IN    15
# MS    15
# NC    15
# CO    15
# WV    15
# WI    15
# IA    15
# TX    15
# UT    15
# ID    15
# HI    15
# OR    15
# MO    15
# NM    15
# KY    15
# MI    15
# GA    15
# ME    15
# WY    15
# OH    15
# CA    15
# KS    15
# WA    15
# LA    15
# ND    15
# AL    15
# MT    15
# PA    15
# NJ    15
# NY    15
# TN    15
# NE    15
# NV    11
# OK     6
# MD     6
# SC     3
# Name: state, dtype: int64

# %%
df['totalprod'].mean()
# Out:
# 4169086.2619808307

# %% [markdown]
# ## calculate the avg production of each state

# %%
#group states

# %%
df[['state','totalprod']].groupby('state').mean().round()
# Out:
#         totalprod
# state
# AL       825467.0
# AR      2810400.0
# AZ      2032267.0
# CA     23169000.0
# CO      1750600.0
# FL     16469867.0
# GA      3299933.0
# HI       843133.0
# IA      2080000.0
# ID      4410667.0
# IL       498333.0
# IN       484000.0
# KS       707933.0
# KY       229667.0
# LA      3627333.0
# MD       211000.0
# ME       246733.0
# MI      4854667.0
# MN      9624000.0
# MO       871533.0
# MS      1456867.0
# MT     10437467.0
# NC       542733.0
# ND     31672333.0
# NE      3158600.0
# NJ       399533.0
# NM       476467.0
# NV       439273.0
# NY      3937467.0
# OH      1040067.0
# OK       201167.0
# OR      2121400.0
# PA      1295600.0
# SC       343333.0
# SD     17742733.0
# TN       407733.0
# TX      6993600.0
# UT      1179067.0
# VA       266533.0
# VT       388067.0
# WA      2687733.0
# WI      5455533.0
# WV       321200.0
# WY      2617933.0

# %%
df['year'].nunique()  #we have total 15 yrs of data
# Out:
# 15

# %%
df['year'].max()
# Out:
# 2012

# %%
df['year'].min()
# Out:
# 1998

# %%
# we have data from 1998 to 2012

# %% [markdown]
# ## which state has seen highest production value and which year?

# %%
df[df['totalprod']==df['totalprod'].max()][['state','year']]
# Out:
#     state  year
# 532    ND  2010

# %%
sns.relplot(x='year',y='totalprod',kind = 'line',data = df)

# %% [markdown]
# ## what is the correlation between all the numerical values

# %%
sns.pairplot(data= df[['numcol','yieldpercol','totalprod','stocks',
                      'priceperlb','prodvalue']] )

# %%
cor = df[['numcol','yieldpercol','totalprod','stocks',
                      'priceperlb','prodvalue']].corr()
cor
# Out:
#                numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue
# numcol       1.000000     0.243515   0.953594  0.825929   -0.232701   0.912796
# yieldpercol  0.243515     1.000000   0.396252  0.367812   -0.358646   0.278977
# totalprod    0.953594     0.396252   1.000000  0.878830   -0.264499   0.907236
# stocks       0.825929     0.367812   0.878830  1.000000   -0.305867   0.728560
# priceperlb  -0.232701    -0.358646  -0.264499 -0.305867    1.000000  -0.089567
# prodvalue    0.912796     0.278977   0.907236  0.728560   -0.089567   1.000000

# %%
sns.heatmap(cor,annot=True, cmap='plasma',vmin = -1,  vmax= 1)

# %% [markdown]
# ## production trend from 1998 to 2012?

# %%
sns.relplot(x= 'year',y = 'totalprod',data = df,kind= 'line',hue='state')

# %%
sns.pointplot(x= 'year',y= 'totalprod',data= df)  #gives better view than line kind as 
#for example, in 2010 the total prod has jumped to high value

# %% [markdown]
# ## production trend for each state?

# %%
eachstateProdTrend = plt.figure(figsize=(10,5))
g =  sns.FacetGrid(df, col= 'state', col_wrap=5 , height = 10)
g = g.map(plt.plot, 'year','totalprod',marker = ".")
eachstateProdTrend.savefig('stateProdtrend.png')

# %%
#from above we could see SD state production overall increased

# %% [markdown]
# ## linear regression - finding linear relationship

# %%
sns.lmplot(x='numcol',y='prodvalue',data = df)

# %%
fig = plt.figure(figsize=(20,10))
sns.boxplot(x='year',y = 'totalprod',data= df)
fig.savefig('prodvsyearBoxplot.png')
