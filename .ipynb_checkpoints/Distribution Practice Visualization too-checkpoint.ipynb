# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("car_sales.csv")
df.head()
# Out:
#    Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura  Integra    Small       12.9   15.9       18.8
# 1           2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi       90  Compact       25.9   29.1       32.3
# 3           4         Audi      100  Midsize       30.8   37.7       44.6
# 4           5          BMW     535i  Midsize       23.7   30.0       36.2
#
#    MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 0        25           31                None  ...          5    177
# 1        18           25  Driver & Passenger  ...          5    195
# 2        20           26         Driver only  ...          5    180
# 3        19           26  Driver & Passenger  ...          6    193
# 4        22           30         Driver only  ...          4    186
#
#    Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make'],
#       dtype='object')

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0 Manufacturer Model     Type  Min.Price      Price  \
# count    93.000000           93    93       93  93.000000  93.000000
# unique         NaN           32    93        6        NaN        NaN
# top            NaN         Ford   Q45  Midsize        NaN        NaN
# freq           NaN            8     1       22        NaN        NaN
# mean     47.000000          NaN   NaN      NaN  17.125806  19.509677
# std      26.990739          NaN   NaN      NaN   8.746029   9.659430
# min       1.000000          NaN   NaN      NaN   6.700000   7.400000
# 25%      24.000000          NaN   NaN      NaN  10.800000  12.200000
# 50%      47.000000          NaN   NaN      NaN  14.700000  17.700000
# 75%      70.000000          NaN   NaN      NaN  20.300000  23.300000
# max      93.000000          NaN   NaN      NaN  45.400000  61.900000
#
#         Max.Price   MPG.city  MPG.highway      AirBags  ... Passengers  \
# ...

# %%
df['Manufacturer'].value_counts()
# Out:
# Ford             8
# Chevrolet        8
# Dodge            6
# Mazda            5
# Pontiac          5
# Buick            4
# Nissan           4
# Volkswagen       4
# Toyota           4
# Hyundai          4
# Oldsmobile       4
# Honda            3
# Subaru           3
# Cadillac         2
# Eagle            2
# Volvo            2
# Geo              2
# Acura            2
# Lexus            2
# Mercedes-Benz    2
# Chrysler         2
# Audi             2
# Mercury          2
# Mitsubishi       2
# Lincoln          2
# Plymouth         1
# Saturn           1
# BMW              1
# Infiniti         1
# Suzuki           1
# Saab             1
# Chrylser         1
# Name: Manufacturer, dtype: int64

# %%
import seaborn as sns

# %%
fig = plt.figure(figsize=(25,10))
sns.countplot(x = 'Manufacturer', data = df)
fig.savefig('Manufacturer_count.png')

# %%
df.hist(column='Price', figsize= (20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CAEEFCCA00>]],
#       dtype=object)

# %%
sns.distplot(df['Price'])

# %%
sns.boxplot(x= 'Price', data = df)

# %%
df.hist(column='Price', by ='DriveTrain', figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CAEEB5E4C0>,
# ...
#       dtype=object)

# %%
sns.countplot(x= 'Type', data = df, hue= 'Origin')

# %%
sns.boxplot(x = 'Type', data = df, y = 'Price')

# %%
sns.countplot(x = 'DriveTrain', data = df)

# %%
ndf = df[['Type','DriveTrain']]
ndf
# Out:
#        Type DriveTrain
# 0     Small      Front
# 1   Midsize      Front
# 2   Compact      Front
# 3   Midsize      Front
# 4   Midsize       Rear
# ..      ...        ...
# 88      Van      Front
# 89  Compact      Front
# 90   Sporty      Front
# 91  Compact       Rear
# 92  Midsize      Front
#
# [93 rows x 2 columns]

# %%
sns.countplot(x = 'Type', data = ndf, hue='DriveTrain')

# %%
df.corr()
# Out:
#                     Unnamed: 0  Min.Price     Price  Max.Price  MPG.city  \
# Unnamed: 0            1.000000  -0.144463 -0.137277  -0.126567  0.161808
# Min.Price            -0.144463   1.000000  0.970601   0.906756 -0.622875
# Price                -0.137277   0.970601  1.000000   0.981580 -0.594562
# Max.Price            -0.126567   0.906756  0.981580   1.000000 -0.547811
# MPG.city              0.161808  -0.622875 -0.594562  -0.547811  1.000000
# MPG.highway           0.137317  -0.579966 -0.560680  -0.522561  0.943936
# EngineSize           -0.338286   0.645488  0.597425   0.535012 -0.710003
# Horsepower           -0.233012   0.802444  0.788218   0.744445 -0.672636
# RPM                   0.167772  -0.042598 -0.004955   0.025015  0.363045
# Rev.per.mile          0.226389  -0.470395 -0.426395  -0.374024  0.695857
# Fuel.tank.capacity   -0.179034   0.635369  0.619480   0.581294 -0.813144
# Passengers           -0.142252   0.061236  0.057860   0.053216 -0.416856
# ...
